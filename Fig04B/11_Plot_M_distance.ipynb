[900, 1.86548354563615, 1.8927954870189, 0.820142857142857, 0.948714285714286],
[900, 1.87019485706114, 1.89149856573139, 0.824714285714286, 0.943857142857143],
[900, 1.86874034204306, 1.89476128383312, 0.819, 0.939285714285714],
[900, 1.87136370026544, 1.89419444662129, 0.822428571428571, 0.948285714285714],
[900, 1.86519392193344, 1.89125319228593, 0.816428571428571, 0.943857142857143],
[1000, 1.8689096205653, 1.89299443876781, 0.823714285714286, 0.950285714285714],
[1000, 1.87194338989804, 1.89165913308037, 0.813714285714286, 0.945571428571429],
[1000, 1.86852291703642, 1.88932158834868, 0.823285714285714, 0.949571428571429],
[1000, 1.86603219102858, 1.88861310608003, 0.812714285714286, 0.945142857142857],
[1000, 1.87187825488236, 1.89561125518318, 0.822142857142857, 0.947285714285714],
[1000, 1.86539209846468, 1.89245537542513, 0.820142857142857, 0.946857142857143],
[1000, 1.87017265494916, 1.89419290043441, 0.824714285714286, 0.945285714285714],
[1000, 1.86879614819528, 1.89493669702901, 0.819, 0.944571428571429],
[1000, 1.87147245803027, 1.89451590110955, 0.822428571428571, 0.951571428571429],
[1000, 1.86524574459171, 1.88957380002269, 0.816428571428571, 0.941]]

data = np.array(data_ori)

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

symbols=["o", "v", "^", "<", ">", "s", "p", "P", "*", "X"]

colors=["#a6cee3",
"#1f78b4",
"#b2df8a",
"#33a02c",
"#fb9a99",
"#e31a1c",
"#fdbf6f",
"#ff7f00",
"#cab2d6",
"#6a3d9a"]


fig, ax = plt.subplots(1,1,figsize=(4.33,1.44))

ax.set_xlim(1.86,1.90)
ax.set_ylim(0.80,0.96)

ax.set_xticks(np.arange(1.86,1.905,0.01), fontsize=8)
ax.set_yticks(np.arange(0.8,0.97,0.04), fontsize=8)

ax.tick_params(labelsize=8)

ax.set_xlabel("Mean Mahalanobis Distance\nacross Pairs of Digits", fontsize=8)
ax.set_ylabel("Correct Rate", fontsize=8)

ax.text(-0.4,0.95,"C",weight="bold",transform=ax.transAxes,fontsize=8)

plots = []
labels = []

np.random.shuffle(data)

for data_i in data:
    symbol_id = int(data_i[0] / 100)-1
#    print(symbol_id)
#    labels.append("N = "+str(N))
    p_tmp = ax.plot(data_i[2], data_i[4], symbols[symbol_id], color=colors[symbol_id], 
                    mfc="None", ls="None")
#    plots.append(plots)

p_tmp = ax.plot(data[data[:,0] == 100, 1], data[data[:,0] == 100, 3], "x", color="black", ls="None", label="Input")

plots.append(p_tmp)

l1element = [
    Line2D([0],[0], ls="None", color=colors[i], mfc="None", marker=symbols[i], label=("N = "+str((i+1)*100)))
    for i in range(10)
]

l2element = [
    Line2D([0],[0], ls="None", color=colors[6+i], mfc="None", marker=symbols[6+i], label=("N = "+str((i+7)*100)))
    for i in range(4)
]

l1element.append(Line2D([0],[0], marker="x", ls="None", color="black", label="Input"))

handles, labels = ax.get_legend_handles_labels()

l1 = plt.legend(handles=l1element, loc=2,ncol=2,fontsize=8,borderpad=0.4, 
                labelspacing=0.2, handlelength=0.2, bbox_to_anchor=(1.1, 0.9))
#l2 = plt.legend(handles=l2element, loc=4,ncol=1,fontsize=8)
#plt.gca().add_artist(l1)

plt.subplots_adjust(left=0.175,
                    bottom=0.35, 
                    right=0.575, 
                    top=0.925, 
                    wspace=0.5, 
                    hspace=0.35)

#plt.tight_layout(pad=0)

plt.savefig("Fig04_2mid.pdf")
